# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("advertising.csv")

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
X = data[['TV', 'Radio', 'Newspaper']]  
y = data['Sales']  
x1 = data['TV']
x2 = data['Radio']
x3 = data['Newspaper']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# beta 1
model.coef_
# Out:
# array([0.05440489, 0.10331182, 0.00165031])

# %%
# beta 0
model.intercept_
# Out:
# 4.753166695546536

# %% [markdown]
# Multiple Linear Regression Model

# %%
y = 4.7141264022141325 + 0.05450927 * x1 + 0.10094536 * x2 + 0.00433665 * x3

# %%
y = 4.7141264022141325 + 0.05450927 * 230.1 + 0.10094536 * 37.8 + 0.00433665 * 69.2
y
# Out:
# 21.372540217214134

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 1.2281962235425268
# Mean Squared Error: 2.6629780626412525
# R-squared: 0.921851097671599

# %%
new_data = np.array([[230.1, 37.8, 69.2]])
new_prediction = model.predict(new_data)
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_prediction
# Out:
# array([21.29111976])

# %%
df = pd.DataFrame({'Actual':y_test, 'predicted':y_pred})
df
# Out:
#      Actual  predicted
# 110    18.4  17.978190
# 124    19.7  20.698513
# 106     7.2   7.298733
# 141    19.2  19.073395
# 56      5.5   8.121707
# 185    22.6  20.597878
# 197    14.8  15.354194
# 71     12.4  12.256497
# 172     7.6   7.924125
# 100    16.7  17.379240
# 3      16.5  17.358829
# 150    16.1  21.521715
# 135    11.6  12.250606
# 105    15.0  17.146637
# 198    25.5  24.630740
# 176    20.2  21.420859
# 1      10.4  11.308768
# 51     10.7  11.213152
# 70     18.3  18.810389
# 127    11.9   9.131622
# 83     13.6  13.130588
# 125    10.6  10.759095
# 155     3.2   6.184051
# 75      8.7  10.334873
# 169    20.0  21.326144
# 109    19.8  21.436340
# 137    20.8  22.728020
# 175    27.0  24.938811
# 74     17.0  18.926260
# 138     9.6   9.802184
# 48     19.8  18.828635
# 15     22.4  20.399157
# 95     16.9  16.989440
# 30     21.4  23.683376
# 147    25.4  23.119823
# 52     22.6  20.899840
# 77     14.2  14.276777
# 61     24.2  23.470851
# 67     13.4  13.846622
# 117     9.4   9.016774

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")

# You can also add a reference line for a perfect match (y = x)
min_val = min(np.min(y_test), np.min(y_pred))
max_val = max(np.max(y_test), np.max(y_pred))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')

plt.show()

# %%
from scipy import stats
r = stats.linregress(y_test, y_pred)
print("R-squared value", r)
# Out:
# R-squared value LinregressResult(slope=0.8995524000294356, intercept=1.9897512539989393, rvalue=0.962776669014107, pvalue=3.426496561117708e-23, stderr=0.0409686988688266, intercept_stderr=0.6980515087423377)

# %%
import pickle

# %%
with open('linear.pkl', 'wb') as file:
    pickle.dump(model, file)
